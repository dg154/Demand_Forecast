# %% [markdown]
# <a href="https://colab.research.google.com/github/dg154/Demand_Forecast/blob/main/DemandForecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/train_0irEZ2H.csv')

# %%
df
# Out:
#         record_ID      week  store_id  sku_id  total_price  base_price  \
# 0               1  17/01/11      8091  216418      99.0375    111.8625
# 1               2  17/01/11      8091  216419      99.0375     99.0375
# 2               3  17/01/11      8091  216425     133.9500    133.9500
# 3               4  17/01/11      8091  216233     133.9500    133.9500
# 4               5  17/01/11      8091  217390     141.0750    141.0750
# ...           ...       ...       ...     ...          ...         ...
# 150145     212638  09/07/13      9984  223245     235.8375    235.8375
# 150146     212639  09/07/13      9984  223153     235.8375    235.8375
# 150147     212642  09/07/13      9984  245338     357.6750    483.7875
# 150148     212643  09/07/13      9984  547934     141.7875    191.6625
# 150149     212644  09/07/13      9984  679023     234.4125    234.4125
#
#         is_featured_sku  is_display_sku  units_sold
# 0                     0               0          20
# 1                     0               0          28
# 2                     0               0          19
# 3                     0               0          44
# 4                     0               0          52
# ...                 ...             ...         ...
# 150145                0               0          38
# 150146                0               0          30
# 150147                1               1          31
# 150148                0               1          12
# 150149                0               0          15
#
# [150150 rows x 9 columns]

# %%
df[['day','month','year']]=df['week'].str.split('/',expand=True)

# %%
df.drop('week', axis=1,inplace=True)

# %%
df
# Out:
#         record_ID  store_id  sku_id  total_price  base_price  is_featured_sku  \
# 0               1      8091  216418      99.0375    111.8625                0
# 1               2      8091  216419      99.0375     99.0375                0
# 2               3      8091  216425     133.9500    133.9500                0
# 3               4      8091  216233     133.9500    133.9500                0
# 4               5      8091  217390     141.0750    141.0750                0
# ...           ...       ...     ...          ...         ...              ...
# 150145     212638      9984  223245     235.8375    235.8375                0
# 150146     212639      9984  223153     235.8375    235.8375                0
# 150147     212642      9984  245338     357.6750    483.7875                1
# 150148     212643      9984  547934     141.7875    191.6625                0
# 150149     212644      9984  679023     234.4125    234.4125                0
#
#         is_display_sku  units_sold day month year
# 0                    0          20  17    01   11
# 1                    0          28  17    01   11
# 2                    0          19  17    01   11
# 3                    0          44  17    01   11
# 4                    0          52  17    01   11
# ...                ...         ...  ..   ...  ...
# 150145               0          38  09    07   13
# 150146               0          30  09    07   13
# 150147               1          31  09    07   13
# 150148               1          12  09    07   13
# 150149               0          15  09    07   13
#
# [150150 rows x 11 columns]

# %%
df.describe()
# Out:
#            record_ID       store_id         sku_id    total_price  \
# count  150150.000000  150150.000000  150150.000000  150149.000000
# mean   106271.555504    9199.422511  254761.132468     206.626751
# std     61386.037861     615.591445   85547.306447     103.308516
# min         1.000000    8023.000000  216233.000000      41.325000
# 25%     53111.250000    8562.000000  217217.000000     130.387500
# 50%    106226.500000    9371.000000  222087.000000     198.075000
# 75%    159452.750000    9731.000000  245338.000000     233.700000
# max    212644.000000    9984.000000  679023.000000     562.162500
#
#           base_price  is_featured_sku  is_display_sku     units_sold
# count  150150.000000    150150.000000   150150.000000  150150.000000
# mean      219.425927         0.095611        0.133200      51.674206
# std       110.961712         0.294058        0.339792      60.207904
# min        61.275000         0.000000        0.000000       1.000000
# 25%       133.237500         0.000000        0.000000      20.000000
# 50%       205.912500         0.000000        0.000000      35.000000
# 75%       234.412500         0.000000        0.000000      62.000000
# max       562.162500         1.000000        1.000000    2876.000000

# %%
df.shape
# Out:
# (150150, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150150 entries, 0 to 150149
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   record_ID        150150 non-null  int64
#  1   store_id         150150 non-null  int64
#  2   sku_id           150150 non-null  int64
#  3   total_price      150149 non-null  float64
#  4   base_price       150150 non-null  float64
#  5   is_featured_sku  150150 non-null  int64
#  6   is_display_sku   150150 non-null  int64
#  7   units_sold       150150 non-null  int64
#  8   day              150150 non-null  object
#  9   month            150150 non-null  object
#  10  year             150150 non-null  object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 12.6+ MB

# %%
df.isnull().sum()
# Out:
# record_ID          0
# store_id           0
# sku_id             0
# total_price        1
# base_price         0
# is_featured_sku    0
# is_display_sku     0
# units_sold         0
# day                0
# month              0
# year               0
# dtype: int64

# %%
df = df.dropna(subset=['total_price'])

# %%
df.isnull().sum()
# Out:
# record_ID          0
# store_id           0
# sku_id             0
# total_price        0
# base_price         0
# is_featured_sku    0
# is_display_sku     0
# units_sold         0
# day                0
# month              0
# year               0
# dtype: int64

# %%
df.shape
# Out:
# (150149, 11)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
x, y = df.drop('units_sold', axis=1), df['units_sold']
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model=RandomForestRegressor(n_jobs=-1)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
model.score(x_test,y_test)
# Out:
# 0.7685133407530491

# %%
from sklearn.metrics import root_mean_squared_error
y_pred=model.predict(x_test)
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 27.523236218839564

# %%
df.units_sold.describe()
# Out:
# count    150149.000000
# mean         51.674543
# std          60.207962
# min           1.000000
# 25%          20.000000
# 50%          35.000000
# 75%          62.000000
# max        2876.000000
# Name: units_sold, dtype: float64

# %%
df.units_sold.hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(y_pred,y_test)
plt.plot(np.linspace(y_pred.min(),y_pred.max()),np.linspace(y_pred.min(),y_pred.max()),color='red')

# %%
df.hist(figsize=(15,8))
plt.show()

# %%
df=df.drop('record_ID', axis=1)

# %%
df
# Out:
#         store_id  sku_id  total_price  base_price  is_featured_sku  \
# 0           8091  216418      99.0375    111.8625                0
# 1           8091  216419      99.0375     99.0375                0
# 2           8091  216425     133.9500    133.9500                0
# 3           8091  216233     133.9500    133.9500                0
# 4           8091  217390     141.0750    141.0750                0
# ...          ...     ...          ...         ...              ...
# 150145      9984  223245     235.8375    235.8375                0
# 150146      9984  223153     235.8375    235.8375                0
# 150147      9984  245338     357.6750    483.7875                1
# 150148      9984  547934     141.7875    191.6625                0
# 150149      9984  679023     234.4125    234.4125                0
#
#         is_display_sku  units_sold day month year
# 0                    0          20  17    01   11
# 1                    0          28  17    01   11
# 2                    0          19  17    01   11
# 3                    0          44  17    01   11
# 4                    0          52  17    01   11
# ...                ...         ...  ..   ...  ...
# 150145               0          38  09    07   13
# 150146               0          30  09    07   13
# 150147               1          31  09    07   13
# 150148               1          12  09    07   13
# 150149               0          15  09    07   13
#
# [150149 rows x 10 columns]

# %%
len(df.store_id.unique())
# Out:
# 76

# %%
len(df.sku_id.unique())
# Out:
# 28

# %%
df=df[df.units_sold<df.units_sold.quantile(0.99)]

# %%
df
# Out:
#         store_id  sku_id  total_price  base_price  is_featured_sku  \
# 0           8091  216418      99.0375    111.8625                0
# 1           8091  216419      99.0375     99.0375                0
# 2           8091  216425     133.9500    133.9500                0
# 3           8091  216233     133.9500    133.9500                0
# 4           8091  217390     141.0750    141.0750                0
# ...          ...     ...          ...         ...              ...
# 150145      9984  223245     235.8375    235.8375                0
# 150146      9984  223153     235.8375    235.8375                0
# 150147      9984  245338     357.6750    483.7875                1
# 150148      9984  547934     141.7875    191.6625                0
# 150149      9984  679023     234.4125    234.4125                0
#
#         is_display_sku  units_sold day month year
# 0                    0          20  17    01   11
# 1                    0          28  17    01   11
# 2                    0          19  17    01   11
# 3                    0          44  17    01   11
# 4                    0          52  17    01   11
# ...                ...         ...  ..   ...  ...
# 150145               0          38  09    07   13
# 150146               0          30  09    07   13
# 150147               1          31  09    07   13
# 150148               1          12  09    07   13
# 150149               0          15  09    07   13
#
# [148635 rows x 10 columns]

# %%
df.units_sold.hist(bins=20)
# Out:
# <Axes: >

# %%
df=df.join(pd.get_dummies(df.store_id,prefix='store')).drop('store_id',axis=1)
df=df.join(pd.get_dummies(df.sku_id,prefix='item')).drop('sku_id',axis=1)

# %%
model=RandomForestRegressor(n_jobs=-1)
x, y = df.drop('units_sold', axis=1), df['units_sold']
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
model.score(x_test,y_test)
# Out:
# 0.8267184321859674

# %%
y_pred=model.predict(x_test)
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 17.795126821252268

# %%
plt.scatter(y_pred,y_test)
plt.plot(np.linspace(y_pred.min(),y_pred.max()),np.linspace(y_pred.min(),y_pred.max()),color='red')

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [150,200],
    'min_samples_split': [3, 5, 10, 20, 50]
}
model=RandomForestRegressor(n_jobs=-1)
grid_search=GridSearchCV(model,param_grid, verbose=2,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ..............min_samples_split=3, n_estimators=150; total time=  42.3s
# [CV] END ..............min_samples_split=3, n_estimators=150; total time=  42.1s
# [CV] END ..............min_samples_split=3, n_estimators=150; total time=  43.2s
# [CV] END ..............min_samples_split=3, n_estimators=150; total time=  43.5s
# [CV] END ..............min_samples_split=3, n_estimators=150; total time=  41.9s
# [CV] END ..............min_samples_split=3, n_estimators=200; total time=  59.3s
# [CV] END ..............min_samples_split=3, n_estimators=200; total time=  56.4s
# [CV] END ..............min_samples_split=3, n_estimators=200; total time=  57.0s
# [CV] END ..............min_samples_split=3, n_estimators=200; total time=  56.9s
# [CV] END ..............min_samples_split=3, n_estimators=200; total time=  57.5s
# [CV] END ..............min_samples_split=5, n_estimators=150; total time=  41.4s
# [CV] END ..............min_samples_split=5, n_estimators=150; total time=  40.5s
# [CV] END ..............min_samples_split=5, n_estimators=150; total time=  41.8s
# [CV] END ..............min_samples_split=5, n_estimators=150; total time=  41.3s
# [CV] END ..............min_samples_split=5, n_estimators=150; total time=  41.4s
# [CV] END ..............min_samples_split=5, n_estimators=200; total time=  54.9s
# [CV] END ..............min_samples_split=5, n_estimators=200; total time=  55.0s
# [CV] END ..............min_samples_split=5, n_estimators=200; total time=  55.2s
# [CV] END ..............min_samples_split=5, n_estimators=200; total time=  54.9s
# [CV] END ..............min_samples_split=5, n_estimators=200; total time=  54.8s
# [CV] END .............min_samples_split=10, n_estimators=150; total time=  38.9s
# [CV] END .............min_samples_split=10, n_estimators=150; total time=  42.1s
# [CV] END .............min_samples_split=10, n_estimators=150; total time=  41.2s
# [CV] END .............min_samples_split=10, n_estimators=150; total time=  39.2s
# [CV] END .............min_samples_split=10, n_estimators=150; total time=  38.1s
# [CV] END .............min_samples_split=10, n_estimators=200; total time=  51.5s
# [CV] END .............min_samples_split=10, n_estimators=200; total time=  51.0s
# [CV] END .............min_samples_split=10, n_estimators=200; total time=  51.1s
# [CV] END .............min_samples_split=10, n_estimators=200; total time=  51.2s
# [CV] END .............min_samples_split=10, n_estimators=200; total time=  51.0s
# [CV] END .............min_samples_split=20, n_estimators=150; total time=  37.1s
# [CV] END .............min_samples_split=20, n_estimators=150; total time=  36.7s
# [CV] END .............min_samples_split=20, n_estimators=150; total time=  36.9s
# [CV] END .............min_samples_split=20, n_estimators=150; total time=  37.1s
# [CV] END .............min_samples_split=20, n_estimators=150; total time=  36.9s
# [CV] END .............min_samples_split=20, n_estimators=200; total time=  49.8s
# [CV] END .............min_samples_split=20, n_estimators=200; total time=  49.9s
# [CV] END .............min_samples_split=20, n_estimators=200; total time=  49.1s
# [CV] END .............min_samples_split=20, n_estimators=200; total time=  49.7s
# [CV] END .............min_samples_split=20, n_estimators=200; total time=  51.3s
# [CV] END .............min_samples_split=50, n_estimators=150; total time=  36.4s
# [CV] END .............min_samples_split=50, n_estimators=150; total time=  35.5s
# [CV] END .............min_samples_split=50, n_estimators=150; total time=  35.6s
# [CV] END .............min_samples_split=50, n_estimators=150; total time=  35.7s
# [CV] END .............min_samples_split=50, n_estimators=150; total time=  34.9s
# [CV] END .............min_samples_split=50, n_estimators=200; total time=  47.4s
# [CV] END .............min_samples_split=50, n_estimators=200; total time=  46.3s
# [CV] END .............min_samples_split=50, n_estimators=200; total time=  46.5s
# [CV] END .............min_samples_split=50, n_estimators=200; total time=  47.1s
# [CV] END .............min_samples_split=50, n_estimators=200; total time=  46.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1),
#              param_grid={'min_samples_split': [3, 5, 10, 20, 50],
#                          'n_estimators': [150, 200]},
#              verbose=2)

# %%
best_model=grid_search.best_estimator_

# %%
grid_search.best_params_
# Out:
# {'min_samples_split': 10, 'n_estimators': 200}

# %%
best_model.score(x_test,y_test)
# Out:
# 0.8289686680462319

# %%
def predict_demand_rf_with_date():
    print("\nEnter details for prediction:")
    date = int(input("Enter day of the month (1-31): "))
    month = int(input("Enter month (1-12): "))
    year = int(input("Enter year (e.g., 2023): "))
    total_price = float(input("Enter total price: "))
    base_price = float(input("Enter base price: "))
    is_featured_sku = int(input("Is the SKU featured? (1 for Yes, 0 for No): "))
    is_display_sku = int(input("Is the SKU displayed? (1 for Yes, 0 for No): "))
    store_id = int(input("Enter store ID: "))
    sku_id = int(input("Enter SKU ID: "))

    # Create a DataFrame for the user input
    user_features = pd.DataFrame([{
        'total_price': total_price,
        'base_price': base_price,
        'is_featured_sku': is_featured_sku,
        'is_display_sku': is_display_sku,
        'day': date,  # Rename 'date' to 'day'
        'month': month,
        'year': year,
        'store_id': store_id,  # Include 'store_id' and 'sku_id'
        'sku_id': sku_id
    }])

    # Apply one-hot encoding to 'store_id' and 'sku_id'
    user_features = pd.get_dummies(user_features, columns=['store_id', 'sku_id'],
                                  prefix=['store', 'item'])

    # Get missing columns from training data
    missing_cols = set(x_train.columns) - set(user_features.columns)

    # Add missing columns to user_features and fill with 0
    for col in missing_cols:
        user_features[col] = 0

    # Ensure the order of columns matches the training data
    user_features = user_features[x_train.columns]

    # Predict demand using the fitted Random Forest model (best_model)
    prediction = best_model.predict(user_features)[0]  # Changed from model to best_model
    print(f"\nPredicted demand for the given input: {prediction:.2f}")

# Call the function to allow user input
predict_demand_rf_with_date()
# Out:
# Enter details for prediction:
# Enter day of the month (1-31): 5
# Enter month (1-12): 3
# Enter year (e.g., 2023): 2025
# Enter total price: 99
# Enter base price: 120
# Is the SKU featured? (1 for Yes, 0 for No): 1
# Is the SKU displayed? (1 for Yes, 0 for No): 1
# Enter store ID: 9986
# Enter SKU ID: 216418
#
# Predicted demand for the given input: 86.65
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0
# <ipython-input-47-1242fec09dd2>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_features[col] = 0

# %%
120
